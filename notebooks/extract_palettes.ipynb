# %% [markdown]
# # Extração de paletas (local)
#
# Este notebook reproduz a geração do arquivo `data/palettes.json` a partir do build público do projeto `dataviz-color-finder`.

# %%
# !python ../scripts/extract_palettes.py

# %%
import json
from pathlib import Path
palettes = json.loads(Path('../data/palettes.json').read_text(encoding='utf-8'))
len(palettes), palettes[0]['name'], palettes[-1]['name']
